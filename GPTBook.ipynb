# %%
import db

data = db.GetStockData(symbol='VND')
length = len(data)
print(data.head())
print(length)
# Out:
#      index       Date Stock   +/-     %  Close     Volume  Open  High   Low  \
# 517    316 2021-01-04   VND  0.15  2.00   7.72  3176700.0  7.57  7.93  7.72
# 516    320 2021-01-05   VND -0.13 -1.63   7.60  6240500.0  7.72  7.74  7.52
# 515    318 2021-01-06   VND -0.04 -0.50   7.56  4625800.0  7.60  7.85  7.50
# 514    317 2021-01-07   VND  0.01  0.17   7.57  5525400.0  7.56  7.65  7.42
# 513    319 2021-01-08   VND -0.10 -1.33   7.47  5535100.0  7.57  7.70  7.42
#
#       NN Mua     NN Ban  GDTT         Money         NN         M(NN)  \
# 517  35800.0    79100.0   0.0  2.452412e+10   -43300.0 -1.375511e+16
# 516  16100.0  2018100.0   0.0  4.742780e+10 -2002000.0 -1.249348e+18
# 515  51300.0   930100.0   0.0  3.497105e+10  -878800.0 -4.065153e+17
# 514  97000.0  1961000.0   0.0  4.182728e+10 -1864000.0 -1.029935e+18
# 513  48500.0  1309000.0   0.0  4.134720e+10 -1260500.0 -6.976994e+17
#
#      Oscillation  Oscillation-Down  Oscillation-Up
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

def estimate_trend(data):
    # Chuyển sang dạng ma trận 2 chiều
    data = data.reshape(-1, 1)
    
    # Xấp xỉ hàm với hồi quy tuyến tính
    reg = LinearRegression().fit(data, data)
    
    # Tính toán giá trị dự đoán
    data_predict = reg.predict(data)
    
    # Tính toán tỷ lệ tăng của dãy số
    data_increase = (data[1:] - data[:-1]) / data[:-1]
    
    # Vẽ đồ thị
    plt.plot(data, 'r', label='Dãy số')
    plt.plot(data_predict, 'b', label='Hàm xấp xỉ')
    plt.legend()
    plt.show()
    
    # In ra tỷ lệ tăng của dãy số
    print("Tỷ lệ tăng của dãy số:", data_increase)

data = db.GetStockData(symbol='FPT')
# Sử dụng hàm với dãy số a
a = data['Close'].to_numpy()
estimate_trend(a)

# Sử dụng hàm với dãy số b
b = np.array([2, 4, 6, 8, 10])
estimate_trend(b)
# Out:
# Tỷ lệ tăng của dãy số: [[ 0.04154476]
#  [-0.00486891]
#  [ 0.00169364]
#  [ 0.01277475]
#  [ 0.02207383]
#  [ 0.01705989]
#  [ 0.01052819]
#  [-0.00141268]
#  [ 0.00300619]
#  [-0.00458392]
#  [-0.06482465]
#  [ 0.02102273]
#  [ 0.03635689]
#  [ 0.01968856]
#  [ 0.00157978]
#  [-0.0148966 ]
#  [-0.0455435 ]
#  [-0.06971109]
#  [ 0.06992587]
#  [ 0.01273408]
#  [ 0.03938609]
#  [ 0.06048746]
#  [ 0.03573226]
#  [ 0.00550696]
#  [-0.02190722]
#  [ 0.046278  ]
#  [ 0.04423107]
#  [ 0.0039192 ]
#  [-0.02042042]
#  [ 0.00260576]
#  [-0.01696988]
#  [-0.00139969]
#  [ 0.01059025]
#  [ 0.        ]
#  [ 0.02234551]
#  [ 0.        ]
#  [-0.00256256]
#  [-0.02312226]
#  [ 0.        ]
#  [-0.00139233]
#  [-0.01053447]
#  [ 0.01737905]
#  [ 0.00523238]
#  [-0.00260257]
#  [ 0.        ]
#  [ 0.05878741]
#  [-0.00246448]
#  [ 0.00247057]
#  [-0.01478689]
#  [-0.01383167]
#  [ 0.00134288]
#  [-0.02279839]
#  [-0.00518451]
#  [-0.00659105]
#  [ 0.01975004]
#  [-0.00650628]
#  [ 0.00776729]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

def estimate_trend(data, degree=2):
    # Chuyển sang dạng ma trận 2 chiều
    data = data.reshape(-1, 1)
    
    # Chuyển dữ liệu sang dạng đa biến
    poly = PolynomialFeatures(degree=degree)
    data_poly = poly.fit_transform(data)
    
    # Xấp xỉ hàm với hồi quy tuyến tính đa biến
    reg = LinearRegression().fit(data_poly, data)
    
    # Tính toán giá trị dự đoán
    data_predict = reg.predict(data_poly)
    
    # Tính toán tỷ lệ tăng của dãy số
    data_increase = (data[1:] - data[:-1]) / data[:-1]
    
    # Vẽ đồ thị
    plt.plot(data, 'r', label='Dãy số')
    plt.plot(data_predict, 'b', label='Hàm xấp xỉ')
    plt.legend()
    plt.show()
    
    # In ra tỷ lệ tăng của dãy số
      # In ra tỷ lệ tăng của dãy số
    print("Tỷ lệ tăng của dãy số:", data_increase)

data = db.GetStockData(symbol='FPT')
# Sử dụng hàm với dãy số a
a = data['Close'].to_numpy()
estimate_trend(a)
# Out:
# Tỷ lệ tăng của dãy số: [[ 0.04154476]
#  [-0.00486891]
#  [ 0.00169364]
#  [ 0.01277475]
#  [ 0.02207383]
#  [ 0.01705989]
#  [ 0.01052819]
#  [-0.00141268]
#  [ 0.00300619]
#  [-0.00458392]
#  [-0.06482465]
#  [ 0.02102273]
#  [ 0.03635689]
#  [ 0.01968856]
#  [ 0.00157978]
#  [-0.0148966 ]
#  [-0.0455435 ]
#  [-0.06971109]
#  [ 0.06992587]
#  [ 0.01273408]
#  [ 0.03938609]
#  [ 0.06048746]
#  [ 0.03573226]
#  [ 0.00550696]
#  [-0.02190722]
#  [ 0.046278  ]
#  [ 0.04423107]
#  [ 0.0039192 ]
#  [-0.02042042]
#  [ 0.00260576]
#  [-0.01696988]
#  [-0.00139969]
#  [ 0.01059025]
#  [ 0.        ]
#  [ 0.02234551]
#  [ 0.        ]
#  [-0.00256256]
#  [-0.02312226]
#  [ 0.        ]
#  [-0.00139233]
#  [-0.01053447]
#  [ 0.01737905]
#  [ 0.00523238]
#  [-0.00260257]
#  [ 0.        ]
#  [ 0.05878741]
#  [-0.00246448]
#  [ 0.00247057]
#  [-0.01478689]
#  [-0.01383167]
#  [ 0.00134288]
#  [-0.02279839]
#  [-0.00518451]
#  [-0.00659105]
#  [ 0.01975004]
#  [-0.00650628]
#  [ 0.00776729]
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def find_correlation(data):
    # Tính toán các trị số liên quan
    price = data['Close']
    volume = data['Volume']
    price_change = price.pct_change()[1:]
    volume_change = volume.pct_change()[1:]
    
    # Tạo dataframe mới chứa các trị số đã tính
    data_corr = pd.DataFrame({'price': price[1:], 'price_change': price_change, 'volume': volume[1:], 'volume_change': volume_change})
    
    # Tính toán mối tương quan giữa các trị số
    corr = data_corr.corr()
    
    # Vẽ heatmap để biểu diễn mối tương quan
    sns.heatmap(corr, annot=True)
    plt.show()
    
    return corr

data = db.GetStockData(symbol='FPT')
corr = find_correlation(data=data)
print(corr)
# Out:
#                   price  price_change    volume  volume_change
# price          1.000000      0.006251  0.099686       0.016707
# price_change   0.006251      1.000000  0.122206       0.103029
# volume         0.099686      0.122206  1.000000       0.469821
# volume_change  0.016707      0.103029  0.469821       1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Tải dữ liệu giá và khối lượng
#data = pd.read_csv('stock_data.csv')

# Chuyển đổi dữ liệu sang dạng chuỗi thời gian
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# Xử lý dữ liệu để chuẩn bị cho việc huấn luyện ARIMA
price = data['Close']

# Chia dữ liệu huấn luyện và kiểm tra
price_train = price[:int(0.8*(len(price)))]
price_test = price[int(0.8*(len(price))):]

# Huấn luyện mô hình ARIMA
model = ARIMA(price_train, order=(5, 1, 0))
model_fit = model.fit()

# Dự báo giá tiếp theo
future_predictions = model_fit.forecast(steps=len(price_test))[0]

# So sánh dự báo với giá thực
plt.plot(price_test)
plt.plot(future_predictions, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:2898, in Index.get_loc(self, key, method, tolerance)
#    2897 try:
# -> 2898     return self._engine.get_loc(casted_key)
#    2899 except KeyError as err:
#
# File pandas/_libs/index.pyx:70, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:101, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:1675, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:1683, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
from statsmodels.tsa.arima.model import ARIMA
import numpy as np

def predict_price(prices, p, d, q):
    model = ARIMA(prices, order=(p, d, q))
    model_fit = model.fit()
    prediction = model_fit.forecast()[0,0]
    return prediction

prices = data['Close']#.tolist() #[100, 110, 105, 115, 120, 125, 130, 135, 140, 145, 150, 155]
prediction = predict_price(prices, 2, 1, 1)
print("Predicted price: ", prediction)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def stock_strategy(data, window1=10, window2=20, holding_period=10):
    close = data['Close']
    ma1 = close.rolling(window=window1).mean()
    ma2 = close.rolling(window=window2).mean()
    signals = pd.DataFrame(index=close.index)
    signals['Close'] = close
    signals['MA10'] = ma1
    signals['MA20'] = ma2
    signals['Buy_MA10'] = np.where(close < ma1, 1, 0)
    signals['Buy_MA20'] = np.where(close < ma2, 1, 0)
    signals['Returns_MA10'] = close.diff(holding_period) / close.shift(holding_period)
    signals['Returns_MA20'] = close.diff(holding_period) / close.shift(holding_period)
    signals = signals.dropna()
    strategy1 = np.log(signals[holding_period:]['Close'] / signals[holding_period:]['Close'].shift(1)) * signals[holding_period:]['Buy_MA10']
    strategy2 = np.log(signals[holding_period:]['Close'] / signals[holding_period:]['Close'].shift(1)) * signals[holding_period:]['Buy_MA20']
    cum_returns_strategy1 = (strategy1 + 1).cumprod()
    cum_returns_strategy2 = (strategy2 + 1).cumprod()
    return cum_returns_strategy1, cum_returns_strategy2

#data = pd.read_csv('stock_data.csv')
cum_returns_strategy1, cum_returns_strategy2 = stock_strategy(data)

plt.plot(cum_returns_strategy1, label='MA10')
plt.plot(cum_returns_strategy2, label='MA20')
plt.legend()
plt.title("Returns of MA10 and MA20 strategies")
plt.xlabel("Time")
plt.ylabel("Cumulative Returns")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate random data
#np.random.seed(0)
x = data['Close'].to_list() #np.random.rand(100, 1)
y = data['Close'].to_list() #2 * x**3 + x**2 + x + np.random.randn(100, 1)

# Split data into training and test set
x_train, y_train = x[:90], y[:90]
x_test, y_test = x[90:], y[90:]

# Fit polynomial regression to the data
poly_reg = PolynomialFeatures(degree=10)
X_poly = poly_reg.fit_transform(x_train)
reg = LinearRegression().fit(X_poly, y_train)

# Predict values on the test set
y_pred = reg.predict(poly_reg.fit_transform(x_test))

# Calculate mean squared error on the test set
mse = np.mean((y_pred - y_test)**2)
print("Mean Squared Error:", mse)

# Plot the data and the polynomial fit
plt.scatter(x_train, y_train, color='blue')
x_linspace = np.linspace(0, 1, 100).reshape(-1, 1)
y_fit = reg.predict(poly_reg.fit_transform(x_linspace))
plt.plot(x_linspace, y_fit, color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb Cell 8 in <module>
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a> # Fit polynomial regression to the data
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X14sZmlsZQ%3D%3D?line=15'>16</a> poly_reg = PolynomialFeatures(degree=10)
# ---> <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a> X_poly = poly_reg.fit_transform(x_train)
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a> reg = LinearRegression().fit(X_poly, y_train)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

def stock_strategy(data):
    # Tính moving average cho ma10 và ma20
    data['ma10'] = data['Close'].rolling(window=10).mean()
    data['ma20'] = data['Close'].rolling(window=20).mean()
    
    # Khởi tạo một số biến
    buy = False
    holding_period = 0
    profit = 0
    trades = []
    
    # Duyệt qua từng phiên giao dịch
    for index, row in data.iterrows():
        if buy == False and row['ma10'] > row['ma20']:
            # Mua vào khi ma10 cắt lên ma20
            buy_price = row['Close']
            buy = True
            holding_period = 1
            trades.append((index, 'Buy', buy_price))
        elif buy == True:
            holding_period += 1
            if holding_period > 10 or row['ma10'] < row['ma20']:
                # Bán ra khi nắm giữ tối đa 10 phiên hoặc ma10 cắt xuống ma20
                sell_price = row['Close']
                profit += sell_price - buy_price
                buy = False
                holding_period = 0
                trades.append((index, 'Sell', sell_price))
    return profit, trades

# Tải dữ liệu cổ phiếu
#data = pd.read_csv('stock_data.csv')

# Sử dụng chương trình stock_strategy để tính toán lợi nhuận và tạo danh sách các lệnh giao dịch
profit, trades = stock_strategy(data)
print('Lợi nhuận:', profit)

# Vẽ đồ thị
plt.plot(data['Close'], label='Close Price')
plt.plot(data['ma10'], label='MA10')
plt.plot(data['ma20'], label='MA20')
plt.legend()

# Đánh dấu và ghi chú từng điểm mua
for trade in trades:
    date = trade[0]
    action = trade[1]
    price = trade[2]
    if action == 'Buy':
        plt.annotate('Buy', (date, price), textcoords='offset points', xytext=(-15,-10), ha='center')
        plt.scatter(date, price, color='green', marker='^')
    elif action == 'Sell':
        plt.annotate('Sell', (date, price), textcoords='offset points', xytext=(15,-10), ha='center')
        plt.scatter(date, price, color='red', marker='v')

plt.title('Phương pháp giao dịch cổ phiếu')
plt.xlabel('Thời gian')
plt.ylabel('Giá')
plt.show()
# Out:
# Lợi nhuận: 2.609999999999978

# %%
import pandas as pd

def manage_stock_orders(data, window):
    # Tính toán giá trung bình
    data["average"] = data["Close"].rolling(window=window).mean()

    # Tạo cột đánh dấu lệnh mua/bán
    data["Order"] = None

    # Tìm điểm mua/bán
    for i in range(window, len(data)):
        if data.loc[i, "Close"] < data.loc[i, "average"]:
            data.loc[i, "Order"] = "Buy"
        elif data.loc[i, "Close"] > data.loc[i, "average"]:
            data.loc[i, "Order"] = "Sell"

    # In ra trạng thái lệnh mua/bán
    print(data[["Close", "average", "Order"]])

# Sử dụng hàm với dữ liệu chứng khoán giả
#data = pd.read_csv("stock_data.csv")
data = db.GetStockData(symbol='VND')
manage_stock_orders(data, 30)
# Out:
#      Close    average Order
# 517   7.72        NaN  None
# 516   7.60        NaN  None
# 515   7.56        NaN  None
# 514   7.57        NaN  None
# 513   7.47        NaN  None
# ..     ...        ...   ...
# 4    15.10  14.826667  None
# 3    15.15  14.815000  None
# 2    14.35  14.786667  None
# 1    14.60  14.785000  None
# 0    14.40  14.780000  None
#
# [518 rows x 3 columns]

# %%
import requests
from bs4 import BeautifulSoup
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer

url = 'https://vnexpress.net/tau-cat-linh-ha-dong-dung-dot-ngot-giua-duong-4569414.html'
response = requests.get(url)
html_content = response.content

soup = BeautifulSoup(html_content, 'html.parser')
text_content = soup.get_text()

#parser = PlaintextParser.from_string(text_content, Tokenizer("english"))
parser = PlaintextParser.from_string(text_content, Tokenizer("vietnam"))
summarizer = LexRankSummarizer()

summary = summarizer(parser.document, 5) # 5 is the number of sentences in the summary

summary_text = '\n'.join([str(sentence) for sentence in summary])

print(summary_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/sumy/nlp/tokenizers.py:172, in Tokenizer._get_sentence_tokenizer(self, language)
#     171     path = to_string("tokenizers/punkt/%s.pickle") % to_string(language)
# --> 172     return nltk.data.load(path)
#     173 except (LookupError, zipfile.BadZipfile) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/nltk/data.py:876, in _open(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# ...

# %%
import pandas as pd
import db
#data = pd.read_csv('stock_data.csv')
data = db.GetStockData(symbol='VND')
price_variation = (data['Close'] - data['Open']) / data['Open'] * 100
volume_variation = (data['Volume'] - data['Volume'].shift(1)) / data['Volume'].shift(1) * 100
open_low_variation = (data['Open'] - data['Low']) / data['Open'] * 100
open_high_variation = (data['Open'] - data['High']) / data['Open'] * 100

data['Price Variation'] = price_variation
data['Volume Variation'] = volume_variation
data['Open Low Variation'] = open_low_variation
data['Open High Variation'] = open_high_variation
price_variation = (data['Close'] - data['Open']) / data['Open']
price_variation_class = ['Positive' if x > 0 else 'Negative' for x in price_variation]

data['Price Variation Class'] = price_variation_class
#print(data.tail())

recent_50_data = data.iloc[-50:]
top_10_biggest_price_drop = recent_50_data.nsmallest(10, 'Price Variation')
print(top_10_biggest_price_drop)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import SARIMAX

#from statsmodels.tsa.arima.model import ARIMA
#model = ARIMA(data, order=(p,d,q))
# Load dữ liệu top_10_biggest_price_drop
data = top_10_biggest_price_drop #pd.read_csv("top_10_biggest_price_drop.csv")

# Chuyển đổi cột 'Date' thành dạng datetime và làm chủ động index của DataFrame
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')

# Chọn cột 'Close' làm dữ liệu đầu vào cho mô hình ARIMA
data = data['Close']

# Chia tập dữ liệu thành 2 phần: tập huấn luyện và tập kiểm tra
training_data = data[:int(0.8*len(data))]
testing_data = data[int(0.8*len(data)):]

# Xây dựng mô hình ARIMA


sarimax_mod = SARIMAX(training_data, rder=(2, 1, 0), trend="c")
sarimax_res = sarimax_mod.fit()
print(sarimax_res.summary())

model_fit = model.fit()

# Dự báo với tập dữ liệu kiểm tra
forecast = model_fit.forecast(steps=len(testing_data))[0]

# Vẽ đồ thị dự báo so với dữ liệu thực tế
plt.plot(testing_data, label="Real Data")
plt.plot(forecast, label="Forecasted Data")
plt.legend()
plt.show()
# Out:
#     index       Date Stock   +/-     %  Close      Volume   Open   High  \
# 7     522 2023-02-01   VND -1.15 -6.95  15.40  47920200.0  16.70  16.75
# 46    483 2022-12-01   VND -0.60 -4.41  13.00  46760300.0  14.05  14.20
# 39    490 2022-12-12   VND -1.05 -6.77  14.45  54105100.0  15.50  15.85
# 3     526 2023-02-07   VND -0.80 -5.28  14.35  23575700.0  15.30  15.40
# 29    500 2022-12-26   VND -0.95 -6.79  13.05  28499900.0  13.85  14.00
# 32    497 2022-12-21   VND -0.55 -3.62  14.65  37810900.0  15.50  15.55
# 34    495 2022-12-19   VND -0.55 -3.43  15.50  46181200.0  16.10  16.90
# 30    499 2022-12-23   VND -0.55 -3.78  14.00  20229500.0  14.50  14.50
# 26    503 2022-12-29   VND -0.60 -4.26  13.50  13180200.0  13.95  14.15
# 6     523 2023-02-02   VND -0.30 -1.95  15.10  26600600.0  15.55  15.60
#
#       Low  ...         NN         M(NN)  Oscillation  Oscillation-Down  \
# 7   15.40  ...   341700.0  1.637433e+18     8.766234         -7.784431
# ...

# %%
import requests

def get_wikipedia_info(query):
    """
    Get summary information from Wikipedia for a given query.
    """
    # Define the API endpoint
    endpoint = "https://en.wikipedia.org/api/rest_v1/page/summary/" + query

    # Send a GET request to the endpoint
    response = requests.get(endpoint)

    # Return the response in JSON format
    return response.json()

# Example usage
result = get_wikipedia_info("Tycho_Brahe_(hố_Sao_Hỏa)")
print(result["title"])
print(result["extract"])
# Out:
# Not found.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb Cell 13 in <module>
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> result = get_wikipedia_info("Tycho_Brahe_(hố_Sao_Hỏa)")
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> print(result["title"])
# ---> <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> print(result["extract"])
#
# KeyError: 'extract'

# %%
import numpy as np
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
from vnstock import *
df =  stock_historical_data(symbol='GMD', 
                            start_date="2022-06-01", 
                            end_date='2023-02-12')
print(df.head())
df['Date'] = df['TradingDate']
print(df.head())
del df['TradingDate']
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date',inplace=True)
print(df.head())

# Vẽ đồ thị candlestick
mpf.plot(df, type='candle', volume=True, style='yahoo')
plt.show()
# Out:
#       Open     High      Low    Close   Volume TradingDate
# 0  57067.0  58335.0  56091.0  56091.0  2953400  2022-06-02
# 1  56091.0  57847.0  55213.0  57067.0  3116200  2022-06-03
# 2  57359.0  60286.0  57067.0  58335.0  7791200  2022-06-06
# 3  58335.0  59993.0  56579.0  59896.0  4032200  2022-06-07
# 4  60481.0  60676.0  58530.0  58628.0  2869800  2022-06-08
#       Open     High      Low    Close   Volume TradingDate       Date
# 0  57067.0  58335.0  56091.0  56091.0  2953400  2022-06-02 2022-06-02
# 1  56091.0  57847.0  55213.0  57067.0  3116200  2022-06-03 2022-06-03
# 2  57359.0  60286.0  57067.0  58335.0  7791200  2022-06-06 2022-06-06
# 3  58335.0  59993.0  56579.0  59896.0  4032200  2022-06-07 2022-06-07
# 4  60481.0  60676.0  58530.0  58628.0  2869800  2022-06-08 2022-06-08
#                Open     High      Low    Close   Volume
# Date
# 2022-06-02  57067.0  58335.0  56091.0  56091.0  2953400
# 2022-06-03  56091.0  57847.0  55213.0  57067.0  3116200
# ...

# %%
import io
import numpy as np
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
from vnstock import *
import datetime

def plot_candlestick_chart(symbol, start_date, end_date):
    df =  stock_historical_data(symbol=symbol, 
                                start_date=start_date, 
                                end_date=end_date)
    df['Date'] = df['TradingDate']
    del df['TradingDate']
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date',inplace=True)
    
    fig, ax = plt.subplots()
    mpf.plot(df, type='candle', volume=True, style='yahoo', addplot=mpf.make_addplot(df['Close'].rolling(14).mean(), panel=1, type='line', linestyle='-.'),ax=ax)

    buffer = io.BytesIO()
    fig.savefig(buffer, format='png')
    buffer.seek(0)
    return buffer

    # fig = plt.subplots()
    # #mpf.plot(df, type='candle', volume=True, style='yahoo', ax=ax)
    # mpf.plot(df, type='candle', volume=True, style='yahoo')
    
    # buffer = io.BytesIO()
    # fig.savefig(buffer, format='png')
    # buffer.seek(0)
    # return buffer


today = datetime.datetime.now()
today_str = today.strftime("%Y-%m-%d")
print("Today's date (yy-dd-m):", today_str)

plot_candlestick_chart(symbol='VND',start_date='2022-06-01',end_date=today_str)
# Out:
# Today's date (yy-dd-m): 2023-02-13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb Cell 15 in <module>
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X22sZmlsZQ%3D%3D?line=36'>37</a> today_str = today.strftime("%Y-%m-%d")
#      <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X22sZmlsZQ%3D%3D?line=37'>38</a> print("Today's date (yy-dd-m):", today_str)
# ---> <a href='vscode-notebook-cell:/Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb#X22sZmlsZQ%3D%3D?line=39'>40</a> plot_candlestick_chart(symbol='VND',start_date='2022-06-01',end_date=today_str)
#
# /Users/taipm/Documents/GitHub/live-capture/GPTBook.ipynb Cell 15 in plot_candlestick_chart(symbol, start_date, end_date)
# ...

# %%
#https://github.com/matplotlib/mplfinance/blob/master/examples/rsi.py
import numpy as np
def relative_strength(prices, n=14):
    """
    compute the n period relative strength indicator
    http://stockcharts.com/school/doku.php?id=chart_school:glossary_r#relativestrengthindex
    http://www.investopedia.com/terms/r/rsi.asp
    """
    deltas = np.diff(prices)
    seed = deltas[:n + 1]
    up = seed[seed >= 0].sum() / n
    down = -seed[seed < 0].sum() / n
    rs = up / down
    rsi = np.zeros_like(prices)
    rsi[:n] = 100. - 100. / (1. + rs)

    for i in range(n, len(prices)):
        delta = deltas[i - 1]  # cause the diff is 1 shorter

        if delta > 0:
            upval = delta
            downval = 0.
        else:
            upval = 0.
            downval = -delta

        up = (up * (n - 1) + upval) / n
        down = (down * (n - 1) + downval) / n

        rs = up / down
        rsi[i] = 100. - 100. / (1. + rs)

    return rsi

# %%
import io
import numpy as np
import pandas as pd
import mplfinance as mpf
import matplotlib.pyplot as plt
from vnstock import *
from ta.momentum import RSIIndicator

def plot_candlestick_chart(symbol, start_date, end_date):
    df =  stock_historical_data(symbol=symbol, 
                                start_date=start_date, 
                                end_date=end_date)
    df['Date'] = df['TradingDate']
    del df['TradingDate']
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date',inplace=True)
    
    df['rsi'] = relative_strength(df['Close'],n=7)
    
    #fig, ax = plt.subplots()
    fig = plt.gcf()
    #mpf.plot(df, type='candle', volume=True, style='yahoo')
    apd = mpf.make_addplot(df['rsi'],panel=2,color='lime',ylim=(10,90),secondary_y=True)
    mpf.plot(df,type='candle',volume=True,style='yahoo',mav=(10,20),figscale=1.5,addplot=apd,panel_ratios=(1,0.6))
    # mpf.plot(df,type='candle',style='charles',volume=True,mav=(10,20),figscale=1.5,addplot=apd,panel_ratios=(1,0.6))
    # mpf.plot(df,type='candle',style='mike',volume=True,mav=(10,20),figscale=1.5,addplot=apd,panel_ratios=(1,0.6))
    # mpf.plot(df,type='candle',style='checkers',volume=True,mav=(10,20),figscale=1.5,addplot=apd,panel_ratios=(1,0.6))
    # mpf.plot(df,type='candle',style='yahoo',volume=True,mav=(10,20),figscale=1.5,addplot=apd,panel_ratios=(1,0.6))
    #plt.legend()
    buffer = io.BytesIO()
    fig.savefig(buffer, format='png')
    buffer.seek(0)
    return buffer



today = datetime.datetime.now()
today_str = today.strftime("%Y-%m-%d")
print("Today's date (yy-dd-m):", today_str)

plot_candlestick_chart(symbol='VND',start_date='2022-06-01',end_date=today_str)
# Out:
# Today's date (yy-dd-m): 2023-02-13

# %%
#import openai


# openai.api_key = api_key

# def generate_answer(prompt):
#     completions = openai.Completion.create(
#         engine="text-davinci-003",
#         prompt=prompt,
#         max_tokens=1024,
#         n=1,
#         stop=None,
#         temperature=0.5,
#     )

#     message = completions.choices[0].text
#     return message
# a = generate_answer(prompt='Lập trình tính nghiệm của phương trình bậc 2 trong Python')
# print(a)


import openai
import pandas as pd
#api_key = "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"
class OpenAIGenerator:
    def __init__(self, api_key):
        openai.api_key = api_key
    
    def generate_answer(self, engines, prompt):
        results = []
        for engine in engines:
            completions = openai.Completion.create(
                engine=engine,
                prompt=prompt,
                max_tokens=1024,
                n=1,
                stop=None,
                temperature=0.5,
            )

            message = completions.choices[0].text
            results.append({'engine': engine, 'question': prompt, 'answer': message})
        return pd.DataFrame(results)


api_key = "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"
openai_generator = OpenAIGenerator(api_key)
engines = ["text-davinci-002", "text-davinci-003"]
questions = ["Lập trình tính nghiệm của phương trình bậc 2 trong Python", "Tạo một trang web bán hàng sử dụng Django"]
results = openai_generator.generate_answer(engines, questions)
print(results.to_markdown())
# Out:
# |    | engine           | question                                                                                                   | answer                                                                              |
# |---:|:-----------------|:-----------------------------------------------------------------------------------------------------------|:------------------------------------------------------------------------------------|
# |  0 | text-davinci-002 | ['Lập trình tính nghiệm của phương trình bậc 2 trong Python', 'Tạo một trang web bán hàng sử dụng Django'] | # phuong trinh bac 2                                                                |
# |    |                  |                                                                                                            | # ax^2 + bx + c = 0                                                                 |
# ...
